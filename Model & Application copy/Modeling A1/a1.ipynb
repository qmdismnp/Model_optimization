# %% [markdown]
# part b

# %%
import pandas as pd
import gurobipy as gp
from gurobipy import Model, GRB, quicksum

# Load data from CSV files
farms = pd.read_csv('/Users/huiyisang/Desktop/Model & Application/farms.csv')
processing = pd.read_csv('/Users/huiyisang/Desktop/Model & Application/processing.csv')
centers = pd.read_csv('/Users/huiyisang/Desktop/Model & Application/centers.csv')

# Extract data from datasets
num_farms = len(farms)
num_processing = len(processing)
num_centers = len(centers)


# Decision variables:
# x[i][j]: amount transported from farm i to processing facility j
# y[j][k]: amount transported from processing facility j to home center k

# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] + processing['Processing_Cost_Per_Ton'][j])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints

# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) == centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) == gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Optimize model
model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for i in range(num_farms):
        for j in range(num_processing):
            if x[i, j].x > 0:
                print(f"Farm {i} to Processing {j}: {x[i, j].x}")
    for j in range(num_processing):
        for k in range(num_centers):
            if y[j, k].x > 0:
                print(f"Processing {j} to Center {k}: {y[j, k].x}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 387 rows, 6318 columns and 17118 nonzeros
# Model fingerprint: 0x79019df7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve time: 0.01s
# Presolved: 387 rows, 6318 columns, 17118 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1171568e+04   2.902000e+04   0.000000e+00      0s
#      370    2.2970900e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 370 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  2.297089973e+06
# Optimal Total Cost: 2297089.9727226268
# Farm 3 to Processing 8: 367.0
# Farm 4 to Processing 5: 499.0
# Farm 5 to Processing 15: 417.0
# Farm 13 to Processing 5: 526.0
# Farm 14 to Processing 8: 441.0
# Farm 25 to Processing 1: 564.0
# Farm 30 to Processing 8: 468.0
# Farm 34 to Processing 0: 476.0
# Farm 35 to Processing 8: 519.0
# Farm 37 to Processing 5: 379.0
# Farm 38 to Processing 0: 489.0
# Farm 42 to Processing 8: 575.0
# Farm 45 to Processing 8: 564.0
# Farm 46 to Processing 15: 552.0
# Farm 51 to Processing 8: 317.0
# Farm 53 to Processing 0: 278.0
# Farm 56 to Processing 8: 306.0
# Farm 61 to Processing 0: 206.0
# Farm 61 to Processing 8: 66.0
# Farm 64 to Processing 15: 225.0
# Farm 65 to Processing 0: 409.0
# Farm 66 to Processing 9: 291.0
# Farm 70 to Processing 0: 508.0
# Farm 72 to Processing 8: 386.0
# Farm 75 to Processing 0: 471.0
# Farm 75 to Processing 15: 76.0
# Farm 84 to Processing 0: 348.0
# Farm 85 to Processing 9: 418.0
# Farm 93 to Processing 1: 239.0
# Farm 93 to Processing 5: 336.0
# Farm 98 to Processing 1: 243.0
# Farm 104 to Processing 8: 522.0
# Farm 106 to Processing 9: 457.0
# Farm 107 to Processing 15: 288.0
# Farm 108 to Processing 9: 122.0
# Farm 108 to Processing 15: 275.0
# Farm 109 to Processing 1: 481.0
# Farm 110 to Processing 8: 399.0
# Farm 120 to Processing 1: 586.0
# Farm 121 to Processing 9: 395.0
# Farm 129 to Processing 8: 538.0
# Farm 130 to Processing 8: 255.0
# Farm 132 to Processing 9: 337.0
# Farm 134 to Processing 15: 533.0
# Farm 140 to Processing 8: 574.0
# Farm 141 to Processing 0: 422.0
# Farm 142 to Processing 8: 398.0
# Farm 144 to Processing 9: 486.0
# Farm 146 to Processing 5: 449.0
# Farm 149 to Processing 9: 247.0
# Farm 150 to Processing 1: 308.0
# Farm 154 to Processing 8: 368.0
# Farm 160 to Processing 8: 472.0
# Farm 164 to Processing 8: 448.0
# Farm 170 to Processing 0: 564.0
# Farm 171 to Processing 5: 289.0
# Farm 182 to Processing 9: 242.0
# Farm 187 to Processing 8: 209.0
# Farm 188 to Processing 1: 495.0
# Farm 191 to Processing 5: 355.0
# Farm 195 to Processing 9: 573.0
# Farm 202 to Processing 5: 519.0
# Farm 203 to Processing 9: 398.0
# Farm 204 to Processing 0: 555.0
# Farm 205 to Processing 0: 313.0
# Farm 209 to Processing 15: 421.0
# Farm 211 to Processing 9: 366.0
# Farm 212 to Processing 0: 406.0
# Farm 217 to Processing 0: 356.0
# Farm 225 to Processing 1: 386.0
# Farm 237 to Processing 5: 269.0
# Farm 239 to Processing 9: 317.0
# Farm 242 to Processing 0: 413.0
# Farm 243 to Processing 1: 255.0
# Processing 0 to Center 6: 480.0
# Processing 0 to Center 7: 149.0
# Processing 0 to Center 9: 469.0
# Processing 0 to Center 14: 320.0
# Processing 0 to Center 17: 437.0
# Processing 0 to Center 19: 258.0
# Processing 0 to Center 20: 327.0
# Processing 0 to Center 22: 127.0
# Processing 0 to Center 39: 150.0
# Processing 0 to Center 40: 474.0
# Processing 0 to Center 48: 105.0
# Processing 0 to Center 51: 336.0
# Processing 0 to Center 53: 490.0
# Processing 0 to Center 57: 122.0
# Processing 0 to Center 60: 315.0
# Processing 0 to Center 69: 112.0
# Processing 0 to Center 78: 371.0
# Processing 0 to Center 80: 370.0
# Processing 0 to Center 84: 342.0
# Processing 0 to Center 89: 168.0
# Processing 0 to Center 95: 292.0
# Processing 1 to Center 0: 82.0
# Processing 1 to Center 11: 267.0
# Processing 1 to Center 13: 147.0
# Processing 1 to Center 35: 183.0
# Processing 1 to Center 36: 245.0
# Processing 1 to Center 37: 439.0
# Processing 1 to Center 46: 486.0
# Processing 1 to Center 54: 228.0
# Processing 1 to Center 61: 496.0
# Processing 1 to Center 73: 211.0
# Processing 1 to Center 83: 443.0
# Processing 1 to Center 85: 225.0
# Processing 1 to Center 88: 105.0
# Processing 5 to Center 2: 464.0
# Processing 5 to Center 23: 450.0
# Processing 5 to Center 25: 147.0
# Processing 5 to Center 31: 129.0
# Processing 5 to Center 34: 277.0
# Processing 5 to Center 44: 132.0
# Processing 5 to Center 45: 476.0
# Processing 5 to Center 58: 264.0
# Processing 5 to Center 67: 68.0
# Processing 5 to Center 74: 292.0
# Processing 5 to Center 75: 194.0
# Processing 5 to Center 79: 484.0
# Processing 5 to Center 87: 118.0
# Processing 5 to Center 100: 126.0
# Processing 8 to Center 1: 348.0
# Processing 8 to Center 4: 340.0
# Processing 8 to Center 5: 86.0
# Processing 8 to Center 10: 473.0
# Processing 8 to Center 18: 455.0
# Processing 8 to Center 21: 255.0
# Processing 8 to Center 24: 377.0
# Processing 8 to Center 26: 395.0
# Processing 8 to Center 29: 385.0
# Processing 8 to Center 30: 143.0
# Processing 8 to Center 32: 87.0
# Processing 8 to Center 38: 331.0
# Processing 8 to Center 42: 343.0
# Processing 8 to Center 50: 489.0
# Processing 8 to Center 52: 260.0
# Processing 8 to Center 55: 457.0
# Processing 8 to Center 59: 437.0
# Processing 8 to Center 64: 403.0
# Processing 8 to Center 65: 283.0
# Processing 8 to Center 68: 162.0
# Processing 8 to Center 77: 130.0
# Processing 8 to Center 82: 362.0
# Processing 8 to Center 86: 425.0
# Processing 8 to Center 91: 469.0
# Processing 8 to Center 93: 104.0
# Processing 8 to Center 99: 193.0
# Processing 9 to Center 3: 161.0
# Processing 9 to Center 12: 138.0
# Processing 9 to Center 16: 286.0
# Processing 9 to Center 27: 414.0
# Processing 9 to Center 28: 399.0
# Processing 9 to Center 33: 457.0
# Processing 9 to Center 41: 124.0
# Processing 9 to Center 43: 257.0
# Processing 9 to Center 47: 192.0
# Processing 9 to Center 49: 410.0
# Processing 9 to Center 63: 320.0
# Processing 9 to Center 66: 368.0
# Processing 9 to Center 72: 326.0
# Processing 9 to Center 76: 195.0
# Processing 9 to Center 90: 253.0
# Processing 9 to Center 97: 285.0
# Processing 9 to Center 98: 64.0
# Processing 15 to Center 8: 72.0
# Processing 15 to Center 13: 111.0
# Processing 15 to Center 15: 470.0
# Processing 15 to Center 56: 107.0
# Processing 15 to Center 62: 122.0
# Processing 15 to Center 70: 421.0
# Processing 15 to Center 71: 233.0
# Processing 15 to Center 81: 92.0
# Processing 15 to Center 92: 464.0
# Processing 15 to Center 94: 87.0
# Processing 15 to Center 96: 250.0
# Processing 15 to Center 101: 358.0

# %% [markdown]
# part c

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] + processing['Processing_Cost_Per_Ton'][j])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints

# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) == centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) == gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")
# Optimize model
model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for i in range(num_farms):
        for j in range(num_processing):
            if x[i, j].x > 0:
                print(f"Farm {i} to Processing {j}: {x[i, j].x} tons")
    for j in range(num_processing):
        for k in range(num_centers):
            if y[j, k].x > 0:
                print(f"Processing {j} to Center {k}: {y[j, k].x} tons")
else:
    print("No optimal solution found.")

# %% [markdown]
# part d

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] + processing['Processing_Cost_Per_Ton'][j])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints

# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) >= centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) >= gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Quality constraint: Only use farms with quality 3 or 4
for i in range(num_farms):
    if farms['Quality'][i] < 3:
        for j in range(num_processing):
            model.addConstr(x[i, j] == 0, name=f"QualityConstraint_Farm{i}_Plant{j}")

# Optimize model
model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for i in range(num_farms):
        for j in range(num_processing):
            if x[i, j].x > 0:
                print(f"Farm {i} to Processing {j}: {x[i, j].x}")
    for j in range(num_processing):
        for k in range(num_centers):
            if y[j, k].x > 0:
                print(f"Processing {j} to Center {k}: {y[j, k].x}")
else:
    print("No optimal solution found.")

# %% [markdown]
# part e 1

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j] + processing['Processing_Cost_Per_Ton'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints

# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) >= centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) >= gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Step 4: Sourcing risk mitigation constraints (Part e)
# Calculate the total raw material sourced across all farms
total_raw_material = gp.quicksum(x[i, j] for i in range(num_farms) for j in range(num_processing))
for j in range(num_processing):
    model.addConstr(gp.quicksum(y[j,k] for k in range(num_centers)) <= 0.03 * total_raw_material, name=f"SourcingRisk_Plant{j}")

model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for i in range(num_farms):
        for j in range(num_processing):
            if x[i, j].x > 0:
                print(f"Farm {i} to Processing {j}: {x[i, j].x} tons")
    for j in range(num_processing):
        for k in range(num_centers):
            if y[j, k].x > 0:
                print(f"Processing {j} to Center {k}: {y[j, k].x} tons")
else:
    print("No optimal solution found.")

# %% [markdown]
# part e 2

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] + processing['Processing_Cost_Per_Ton'][j])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints
# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) == centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) == gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Supply risk mitigation: No processing facility can supply more than 50% of a single center's demand
for k in range(num_centers):
    center_demand = centers['Requested_Demand_Tons'][k]
    for j in range(num_processing):
        model.addConstr(y[j, k] <= 0.5*center_demand, name=f"SupplyRisk_Plant{j}_Center{k}")


# Optimize model
model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
    for i in range(num_farms):
        for j in range(num_processing):
            if x[i, j].x > 0:
                print(f"Farm {i} to Processing {j}: {x[i, j].x}")
    for j in range(num_processing):
        for k in range(num_centers):
            if y[j, k].x > 0:
                print(f"Processing {j} to Center {k}: {y[j, k].x}")
else:
    print("No optimal solution found.")

# %% [markdown]
# part f

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] + processing['Processing_Cost_Per_Ton'][j])
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints
# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) == centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) == gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Region constraints: Processing plants can only send to centers in the same region
for j in range(num_processing):
    for k in range(num_centers):
        if processing['Region'][j] != centers['Region'][k]:
            model.addConstr(y[j, k] == 0, name=f"RegionConstraint_Plant{j}_Center{k}")

# Supply risk mitigation: No processing facility can supply more than 50% of a single center's demand
for k in range(num_centers):
    center_demand = centers['Requested_Demand_Tons'][k]
    for j in range(num_processing):
        model.addConstr(y[j, k] <= 0.5*center_demand, name=f"SupplyRisk_Plant{j}_Center{k}")

# Optimize the model
model.optimize()

if model.status == GRB.OPTIMAL:
    print(f"Optimal Cost: {model.objVal}")
    print("Farm to Plant Transportation:")
    for i in range(len(farms)):
        for j in range(len(processing)):
            if x[i, j].x > 0:
                print(f"Farm {i} to Plant {j}: {x[i, j].x} tons")
    print("\nPlant to Center Transportation:")
    for j in range(len(processing)):
        for k in range(len(centers)):
            if y[j, k].x > 0:
                print(f"Plant {j} to Center {k}: {y[j, k].x} tons")
else:
    print("No optimal solution found.")

# %% [markdown]
# part h

# %%
# Create model
model = gp.Model("Transportation_Procurement_Plan")

# Decision variables
x = model.addVars(num_farms, num_processing, lb=0, vtype=GRB.CONTINUOUS, name="FarmToProc")
y = model.addVars(num_processing, num_centers, lb=0, vtype=GRB.CONTINUOUS, name="ProcToCenter")

# Objective function: Minimize total cost
model.setObjective(
    gp.quicksum(
        x[i, j] * (farms[f'Transport_Cost_To_Plant_{j+1}'][i] + farms['Cost_Per_Ton'][i] )
        for i in range(num_farms) for j in range(num_processing)
    ) +
    gp.quicksum(
        y[j, k] * (processing[f'Transport_Cost_To_Center_{k+1}'][j] + processing['Processing_Cost_Per_Ton'][j])
        for j in range(num_processing) for k in range(num_centers)
    ),
    GRB.MINIMIZE
)

# Constraints
# Supply constraints at farms: Cannot exceed available material
for i in range(num_farms):
    model.addConstr(gp.quicksum(x[i, j] for j in range(num_processing)) <= farms['Bio_Material_Capacity_Tons'][i], name=f"FarmSupply_{i}")

# Capacity constraints at processing facilities
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) <= processing['Capacity_Tons'][j], name=f"ProcCapacity_{j}")

# Demand constraints at home centers
for k in range(num_centers):
    model.addConstr(gp.quicksum(y[j, k] for j in range(num_processing)) >= centers['Requested_Demand_Tons'][k], name=f"CenterDemand_{k}")

# Linking constraint: processed material must be transported to centers
for j in range(num_processing):
    model.addConstr(gp.quicksum(x[i, j] for i in range(num_farms)) >= gp.quicksum(y[j, k] for k in range(num_centers)), name=f"Balance_{j}")

# Region constraints: Processing plants can only send to centers in the same region
for j in range(num_processing):
    for k in range(num_centers):
        if processing['Region'][j] != centers['Region'][k]:
            model.addConstr(y[j, k] == 0, name=f"RegionConstraint_Plant{j}_Center{k}")

# Supply risk mitigation: No processing facility can supply more than 50% of a single center's demand
for k in range(num_centers):
    center_demand = centers['Requested_Demand_Tons'][k]
    for j in range(num_processing):
        model.addConstr(y[j, k] <= 0.5*center_demand, name=f"SupplyRisk_Plant{j}_Center{k}")

# Step 4: Sourcing risk mitigation constraints (Part e)
# Calculate the total raw material sourced across all farms
total_raw_material = gp.quicksum(x[i, j] for i in range(num_farms) for j in range(num_processing))

for j in range(num_processing):
    model.addConstr(gp.quicksum(y[j,k] for k in range(num_centers)) <= 0.024 * total_raw_material, name=f"SourcingRisk_Plant{j}")

model.optimize()

# Output results
if model.status == GRB.OPTIMAL:
    print(f"Optimal Total Cost: {model.objVal}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3615 rows, 6318 columns and 102840 nonzeros
# Model fingerprint: 0xaa6a9785
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+00]
#   Objective range  [6e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 3e+04]
# Presolve removed 3210 rows and 1374 columns
# Presolve time: 0.02s
# Presolved: 405 rows, 4944 columns, 95508 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.519e+04
#  Factor NZ  : 2.008e+04 (roughly 2 MB of memory)
#  Factor Ops : 1.345e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.49817786e+09 -7.86124916e+06  5.07e+05 1.14e-13  1.32e+06     0s
#    1   8.72429011e+08 -1.69270403e+07  4.43e+04 1.14e+01  1.23e+05     0s
#    2   1.63460579e+08 -1.24808176e+07  6.05e+03 1.69e-12  2.30e+04     0s
#
# Barrier performed 2 iterations in 0.04 seconds (0.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Solved in 628 iterations and 0.04 seconds (0.05 work units)
# Infeasible model
# No optimal solution found.
